# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/My Drive/haftalık çalışmalar/hafta4')
# !pwd

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe=pd.read_csv('d_regresyon.csv')
dataframe.head()

# %%
# plot data
plt.scatter(dataframe.deneyim,dataframe.maas)
plt.xlabel('deneyim')
plt.ylabel('maas')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_reg=LinearRegression()
x=dataframe.deneyim.values.reshape(-1,1)
y=dataframe.maas.values.reshape(-1,1)

# %%
linear_reg.fit(x,y)

# %%
tahmin=linear_reg.predict([[15]])
print(tahmin)
